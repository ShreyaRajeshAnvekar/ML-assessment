# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyaRajeshAnvekar/ML-assessment/blob/main/LR_Multi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('/content/sample_data/california_housing_test.csv')
x=data[['total_rooms','total_bedrooms']]
y=data[['households']]
print(x)
print('\n')
print(y)
plt.plot(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)

from sklearn.metrics import mean_squared_log_error
mse=mean_squared_log_error(y,pred)
plt.plot(x,pred,color='g',marker='*')
print("MSE:",mse)
print("intercept",SLR.intercept_)
print("Slope:",SLR.coef_)
# Out:
#       total_rooms  total_bedrooms
# 0          3885.0           661.0
# 1          1510.0           310.0
# 2          3589.0           507.0
# 3            67.0            15.0
# 4          1241.0           244.0
# ...           ...             ...
# 2995       1450.0           642.0
# 2996       5257.0          1082.0
# 2997        956.0           201.0
# 2998         96.0            14.0
# 2999       1765.0           263.0
#
# [3000 rows x 2 columns]
#
#
#       households
# 0          606.0
# 1          277.0
# 2          495.0
# 3           11.0
# 4          237.0
# ...          ...
# 2995       607.0
# 2996      1036.0
# 2997       220.0
# 2998        14.0
# 2999       260.0
#
# [3000 rows x 1 columns]
# MSE: 0.05576275916372558
# intercept [37.51101171]
# Slope: [[0.00532517 0.82754456]]
