# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyaRajeshAnvekar/ML-assessment/blob/main/LRrandom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

x=np.random.randint(1,100,10).reshape((-1,1))
y=np.random.randint(1,100,10)
print(x)
print(y)
plt.scatter(x,y)
plt.xlabel("IV")
plt.xlabel("DV")

from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)

from sklearn.metrics import mean_squared_log_error
mse=mean_squared_log_error(y,pred)
plt.plot(x,pred,color='g',marker='*')
print("MSE:",mse)
print("intercept",SLR.intercept_)
print("Slope:",SLR.coef_)
# Out:
# [[86]
#  [41]
#  [33]
#  [97]
#  [20]
#  [47]
#  [60]
#  [93]
#  [60]
#  [16]]
# [79 22 61 32 15 90  8 94 78  2]
# MSE: 1.0005782001623476
# intercept 14.5409115086727
# Slope: [0.60685513]

# %%
# Out:
# [[91]
#  [46]
#  [63]
#  [65]
#  [10]
#  [53]
#  [51]
#  [ 1]
#  [33]
#  [10]]
# [54 70 40 30  6  8  4 98 76 71]
# Text(0.5, 0, 'DV')

# %%
# Out:
# MSE: 1.27381679869721
# intercept 61.269826036414756
# Slope: [-0.36808099]
